# %% [markdown]
# # 高级机器学习作业
# ## 实验目的及要求：
#     1.尝试构建一个基于LeNet更复杂的网络，以提高其准确性
#     2.在MNIST数据集上尝试以上改进的网络
# ## 实验内容：
#     （1）在原LeNet网络基础上调整卷积窗口大小
#     （2）在原LeNet网络基础上调整输出通道数量
#     （3）在原LeNet网络基础上调整激活函数（如ReLU）
#     （4）在原LeNet网络基础上调整卷积层的数量
#     （5）在原LeNet网络基础上调整全连接的数量
#     （6）在原LeNet网络基础上调整学习率和其他训练细节
#     （7）在MNIST数据集上尝试以上改进网络

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Define the LeNet model
model = Sequential()
# 卷积窗口大小为5
# model.add(Conv2D(6, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1)))
#调整卷积窗口大小为6
#输出通道数量为6，第一个参数
#model.add(Conv2D(6, kernel_size=(4, 4), activation='relu', input_shape=(28, 28, 1)))
#调整输出通道数量为8
#激活函数为relu
#model.add(Conv2D(8, kernel_size=(4, 4), activation='relu', input_shape=(28, 28, 1)))
# 调整激活函数为sigmoid
model.add(Conv2D(8, kernel_size=(4, 4), activation='sigmoid', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 卷积窗口大小为5
#调整卷积窗口大小为6
# model.add(Conv2D(16, kernel_size=(5, 5), activation='relu'))
#输出通道数量为16，
model.add(Conv2D(16, kernel_size=(4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 增加一个卷积层
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


#全连接层
model.add(Flatten())
# 增加一个全连接层
model.add(Dense(256,activation='relu'))
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile and train the model
# 学习率为adam的默认值,通常为0.001
# 修改学习率
custom_learning_rate = 0.002
optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/15
# 469/469 [==============================] - 8s 17ms/step - loss: 0.7766 - accuracy: 0.7330 - val_loss: 0.2407 - val_accuracy: 0.9246
# Epoch 2/15
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2218 - accuracy: 0.9309 - val_loss: 0.1834 - val_accuracy: 0.9395
# Epoch 3/15
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1571 - accuracy: 0.9505 - val_loss: 0.1299 - val_accuracy: 0.9584
# Epoch 4/15
# 469/469 [==============================] - 7s 16ms/step - loss: 0.1254 - accuracy: 0.9608 - val_loss: 0.1250 - val_accuracy: 0.9609
# Epoch 5/15
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1102 - accuracy: 0.9651 - val_loss: 0.0897 - val_accuracy: 0.9711
# Epoch 6/15
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0973 - accuracy: 0.9696 - val_loss: 0.0833 - val_accuracy: 0.9732
# Epoch 7/15
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0855 - accuracy: 0.9725 - val_loss: 0.0793 - val_accuracy: 0.9761
# Epoch 8/15
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0801 - accuracy: 0.9747 - val_loss: 0.0892 - val_accuracy: 0.9711
# Epoch 9/15
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0773 - accuracy: 0.9747 - val_loss: 0.0679 - val_accuracy: 0.9789
# Epoch 10/15
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0724 - accuracy: 0.9767 - val_loss: 0.0988 - val_accuracy: 0.9682
# Epoch 11/15
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0676 - accuracy: 0.9785 - val_loss: 0.0649 - val_accuracy: 0.9791
# Epoch 12/15
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0618 - accuracy: 0.9807 - val_loss: 0.0875 - val_accuracy: 0.9736
# Epoch 13/15
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0613 - accuracy: 0.9801 - val_loss: 0.0863 - val_accuracy: 0.9736
# Epoch 14/15
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0583 - accuracy: 0.9818 - val_loss: 0.0664 - val_accuracy: 0.9787
# Epoch 15/15
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0534 - accuracy: 0.9824 - val_loss: 0.0671 - val_accuracy: 0.9812
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0671 - accuracy: 0.9812
# Test loss: 0.06709831207990646
# Test accuracy: 0.9811999797821045

# %%
# 原模型代码
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Define the LeNet model
model = Sequential()
# 输出通道为6，卷积窗口大小为5，激活函数为relu,定义了两个卷积层，三个全连接层，学习率使用的是adam
# 默认值，一般为0.001，epochs为10
model.add(Conv2D(6, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(16, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile and train the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.3411 - accuracy: 0.8979 - val_loss: 0.0875 - val_accuracy: 0.9730
# Epoch 2/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0816 - accuracy: 0.9752 - val_loss: 0.0548 - val_accuracy: 0.9837
# Epoch 3/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0564 - accuracy: 0.9829 - val_loss: 0.0495 - val_accuracy: 0.9828
# Epoch 4/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0448 - accuracy: 0.9857 - val_loss: 0.0395 - val_accuracy: 0.9875
# Epoch 5/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0356 - accuracy: 0.9893 - val_loss: 0.0352 - val_accuracy: 0.9887
# Epoch 6/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0312 - accuracy: 0.9902 - val_loss: 0.0358 - val_accuracy: 0.9889
# Epoch 7/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0274 - accuracy: 0.9911 - val_loss: 0.0337 - val_accuracy: 0.9890
# Epoch 8/10
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0217 - accuracy: 0.9932 - val_loss: 0.0299 - val_accuracy: 0.9895
# Epoch 9/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0208 - accuracy: 0.9933 - val_loss: 0.0321 - val_accuracy: 0.9893
# Epoch 10/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0175 - accuracy: 0.9944 - val_loss: 0.0339 - val_accuracy: 0.9882
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0339 - accuracy: 0.9882
# Test loss: 0.03385716676712036
# Test accuracy: 0.9882000088691711

# %%
# 调整模型代码
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Define the LeNet model
model = Sequential()
# 输出通道为6，卷积窗口大小为5，激活函数为relu,定义了两个卷积层，三个全连接层，学习率使用的是adam
# 默认值，一般为0.001，epochs为10
# 调整输出通道为8，卷积窗口为6
model.add(Conv2D(8, kernel_size=(6, 6), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 调整输出通道为20，卷积窗口为6
model.add(Conv2D(16, kernel_size=(6, 6), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile and train the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 9s 18ms/step - loss: 0.3317 - accuracy: 0.9048 - val_loss: 0.1018 - val_accuracy: 0.9679
# Epoch 2/10
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0919 - accuracy: 0.9718 - val_loss: 0.0594 - val_accuracy: 0.9798
# Epoch 3/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0657 - accuracy: 0.9798 - val_loss: 0.0565 - val_accuracy: 0.9828
# Epoch 4/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0531 - accuracy: 0.9835 - val_loss: 0.0498 - val_accuracy: 0.9839
# Epoch 5/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0440 - accuracy: 0.9864 - val_loss: 0.0439 - val_accuracy: 0.9855
# Epoch 6/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0365 - accuracy: 0.9890 - val_loss: 0.0378 - val_accuracy: 0.9868
# Epoch 7/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0330 - accuracy: 0.9896 - val_loss: 0.0430 - val_accuracy: 0.9865
# Epoch 8/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0290 - accuracy: 0.9906 - val_loss: 0.0377 - val_accuracy: 0.9887
# Epoch 9/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0269 - accuracy: 0.9914 - val_loss: 0.0331 - val_accuracy: 0.9890
# Epoch 10/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0227 - accuracy: 0.9928 - val_loss: 0.0305 - val_accuracy: 0.9906
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0305 - accuracy: 0.9906
# Test loss: 0.030540667474269867
# Test accuracy: 0.9905999898910522

# %%
# 调整模型代码 激活函数
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Define the LeNet model
model = Sequential()
# 输出通道为6，卷积窗口大小为5，激活函数为relu,定义了两个卷积层，三个全连接层，学习率使用的是adam
# 默认值，一般为0.001，epochs为10
# 调整输出通道为8，卷积窗口为6
model.add(Conv2D(8, kernel_size=(6, 6), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 调整输出通道为20，卷积窗口为6
# 将激活函数调整为sigmoid
model.add(Conv2D(16, kernel_size=(6, 6), activation='sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile and train the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.5866 - accuracy: 0.8182 - val_loss: 0.1707 - val_accuracy: 0.9438
# Epoch 2/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.1308 - accuracy: 0.9587 - val_loss: 0.1146 - val_accuracy: 0.9613
# Epoch 3/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0907 - accuracy: 0.9714 - val_loss: 0.0809 - val_accuracy: 0.9736
# Epoch 4/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0756 - accuracy: 0.9764 - val_loss: 0.0630 - val_accuracy: 0.9790
# Epoch 5/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0628 - accuracy: 0.9803 - val_loss: 0.0644 - val_accuracy: 0.9790
# Epoch 6/10
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0550 - accuracy: 0.9825 - val_loss: 0.0510 - val_accuracy: 0.9839
# Epoch 7/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0475 - accuracy: 0.9852 - val_loss: 0.0532 - val_accuracy: 0.9832
# Epoch 8/10
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0422 - accuracy: 0.9863 - val_loss: 0.0518 - val_accuracy: 0.9840
# Epoch 9/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0381 - accuracy: 0.9876 - val_loss: 0.0539 - val_accuracy: 0.9838
# Epoch 10/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0339 - accuracy: 0.9896 - val_loss: 0.0567 - val_accuracy: 0.9827
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0567 - accuracy: 0.9827
# Test loss: 0.05672072619199753
# Test accuracy: 0.982699990272522

# %%
# 调整模型代码 增加卷积层
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Define the LeNet model
model = Sequential()
# 输出通道为6，卷积窗口大小为5，激活函数为relu,定义了两个卷积层，三个全连接层，学习率使用的是adam
# 默认值，一般为0.001，epochs为10
# 调整输出通道为8，卷积窗口为6
model.add(Conv2D(8, kernel_size=(6, 6), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 调整输出通道为20，卷积窗口为6
# 将激活函数调整为sigmoid
model.add(Conv2D(16, kernel_size=(6, 6), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 增加一个卷积层
model.add(Conv2D(32, kernel_size=(2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile and train the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.4745 - accuracy: 0.8517 - val_loss: 0.1644 - val_accuracy: 0.9493
# Epoch 2/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.1501 - accuracy: 0.9540 - val_loss: 0.1271 - val_accuracy: 0.9587
# Epoch 3/10
# 469/469 [==============================] - 9s 18ms/step - loss: 0.1087 - accuracy: 0.9669 - val_loss: 0.0933 - val_accuracy: 0.9720
# Epoch 4/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0903 - accuracy: 0.9721 - val_loss: 0.0909 - val_accuracy: 0.9722
# Epoch 5/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0791 - accuracy: 0.9758 - val_loss: 0.0610 - val_accuracy: 0.9819
# Epoch 6/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0676 - accuracy: 0.9790 - val_loss: 0.0812 - val_accuracy: 0.9740
# Epoch 7/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0616 - accuracy: 0.9809 - val_loss: 0.0581 - val_accuracy: 0.9815
# Epoch 8/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0573 - accuracy: 0.9828 - val_loss: 0.0574 - val_accuracy: 0.9821
# Epoch 9/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0500 - accuracy: 0.9845 - val_loss: 0.0760 - val_accuracy: 0.9740
# Epoch 10/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0491 - accuracy: 0.9842 - val_loss: 0.0584 - val_accuracy: 0.9818
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0584 - accuracy: 0.9818
# Test loss: 0.05838500335812569
# Test accuracy: 0.9818000197410583

# %%
# 调整模型代码 增加卷积层
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Define the LeNet model
model = Sequential()
# 输出通道为6，卷积窗口大小为5，激活函数为relu,定义了两个卷积层，三个全连接层，学习率使用的是adam
# 默认值，一般为0.001，epochs为10
# 调整输出通道为8，卷积窗口为6
model.add(Conv2D(8, kernel_size=(6, 6), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 调整输出通道为20，卷积窗口为6
# 将激活函数调整为sigmoid
model.add(Conv2D(16, kernel_size=(6, 6), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 增加一个卷积层
model.add(Conv2D(32, kernel_size=(2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
# 增加一个全连接层
model.add(Dense(256, activation='relu'))
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile and train the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.4627 - accuracy: 0.8559 - val_loss: 0.1418 - val_accuracy: 0.9566
# Epoch 2/10
# 469/469 [==============================] - 9s 18ms/step - loss: 0.1359 - accuracy: 0.9585 - val_loss: 0.0976 - val_accuracy: 0.9691
# Epoch 3/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0988 - accuracy: 0.9693 - val_loss: 0.0837 - val_accuracy: 0.9747
# Epoch 4/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0821 - accuracy: 0.9744 - val_loss: 0.0776 - val_accuracy: 0.9756
# Epoch 5/10
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0715 - accuracy: 0.9781 - val_loss: 0.0651 - val_accuracy: 0.9800
# Epoch 6/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0600 - accuracy: 0.9818 - val_loss: 0.0577 - val_accuracy: 0.9808
# Epoch 7/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0547 - accuracy: 0.9825 - val_loss: 0.0583 - val_accuracy: 0.9812
# Epoch 8/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0481 - accuracy: 0.9848 - val_loss: 0.0575 - val_accuracy: 0.9800
# Epoch 9/10
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0424 - accuracy: 0.9865 - val_loss: 0.0620 - val_accuracy: 0.9788
# Epoch 10/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0411 - accuracy: 0.9871 - val_loss: 0.0475 - val_accuracy: 0.9853
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0475 - accuracy: 0.9853
# Test loss: 0.04748358204960823
# Test accuracy: 0.9853000044822693

# %%
# 调整模型代码 增加卷积层
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Define the LeNet model
model = Sequential()
# 输出通道为6，卷积窗口大小为5，激活函数为relu,定义了两个卷积层，三个全连接层，学习率使用的是adam
# 默认值，一般为0.001，epochs为10
# 调整输出通道为8，卷积窗口为6
model.add(Conv2D(8, kernel_size=(6, 6), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 调整输出通道为20，卷积窗口为6
# 将激活函数调整为sigmoid
model.add(Conv2D(16, kernel_size=(6, 6), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 增加一个卷积层
model.add(Conv2D(32, kernel_size=(2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
# 增加两个全连接层
model.add(Dense(256, activation='relu'))
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile and train the model
# 设置学习率为0.02，调整epochs为20

custom_learning_rate = 0.002
optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=128, epochs=20, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.3644 - accuracy: 0.8830 - val_loss: 0.1247 - val_accuracy: 0.9611
# Epoch 2/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.1095 - accuracy: 0.9664 - val_loss: 0.0883 - val_accuracy: 0.9707
# Epoch 3/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0774 - accuracy: 0.9762 - val_loss: 0.0762 - val_accuracy: 0.9743
# Epoch 4/20
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0664 - accuracy: 0.9788 - val_loss: 0.0515 - val_accuracy: 0.9849
# Epoch 5/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0559 - accuracy: 0.9827 - val_loss: 0.0587 - val_accuracy: 0.9817
# Epoch 6/20
# 469/469 [==============================] - 10s 20ms/step - loss: 0.0481 - accuracy: 0.9847 - val_loss: 0.0513 - val_accuracy: 0.9845
# Epoch 7/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0444 - accuracy: 0.9860 - val_loss: 0.0437 - val_accuracy: 0.9868
# Epoch 8/20
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0417 - accuracy: 0.9870 - val_loss: 0.0535 - val_accuracy: 0.9826
# Epoch 9/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0385 - accuracy: 0.9881 - val_loss: 0.0640 - val_accuracy: 0.9816
# Epoch 10/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0380 - accuracy: 0.9873 - val_loss: 0.0508 - val_accuracy: 0.9864
# Epoch 11/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0362 - accuracy: 0.9887 - val_loss: 0.0437 - val_accuracy: 0.9875
# Epoch 12/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0326 - accuracy: 0.9901 - val_loss: 0.0442 - val_accuracy: 0.9867
# Epoch 13/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0290 - accuracy: 0.9913 - val_loss: 0.0496 - val_accuracy: 0.9863
# Epoch 14/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0294 - accuracy: 0.9908 - val_loss: 0.0547 - val_accuracy: 0.9853
# Epoch 15/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0288 - accuracy: 0.9910 - val_loss: 0.0577 - val_accuracy: 0.9842
# Epoch 16/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0244 - accuracy: 0.9923 - val_loss: 0.0459 - val_accuracy: 0.9870
# Epoch 17/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0242 - accuracy: 0.9922 - val_loss: 0.0516 - val_accuracy: 0.9872
# Epoch 18/20
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0227 - accuracy: 0.9931 - val_loss: 0.0454 - val_accuracy: 0.9882
# Epoch 19/20
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0207 - accuracy: 0.9937 - val_loss: 0.0513 - val_accuracy: 0.9873
# Epoch 20/20
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0212 - accuracy: 0.9934 - val_loss: 0.0527 - val_accuracy: 0.9869
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0527 - accuracy: 0.9869
# Test loss: 0.05267702788114548
# Test accuracy: 0.9868999719619751
